# %% [markdown]
# # **Football Data Task 4 : Web Scraping Football UnderStat with Beautiful Soup - Aston Villa vs Arsenal 2024/2025** #
# ### **Background** ###
#
# This notebook provides a step by step guide to scraping football match data from UnderStat.
# We will make a program which will extract shot data from a specfic match, given a user inputted Match ID. Match ID's can be found in the URL of any desired match on UnderStat. In this example we
# will be scraping shot data for the Aston Villa vs. Arsenal match which took place on 25/09/2024
# <br>
#
# ### **Step by Step Guide** ###
# Here’s a step-by-step guide to the process:
# <br>
#
# 1) **Ask the User for the Understat Match ID :** Prompt the User for Match ID: Obtain the match ID from the user, which will be used to construct the URL.
#
# 2) **Make Inital HTML Requests :** Send requests to the UnderStat website to retrieve the HTML content of the match page.
#
# 3) **Scrape HTML with BeautifulSoup:** Use BeautifulSoup to parse the HTML and extract shot data in JSON format.
#
# 4) **Convert JSON to Python Dictionary:** Transform the JSON data into a Python dictionary for easier manipulation.
#
# 5) **Organize Data:** Initialize lists to organize the shot information separately for home and away teams.
#
# 6) **Populate Data Structures:** Populate these lists with data from the Python dictionary.
#
# 7) **Construct a DataFrame:** Construct a DataFrame from the organized data.
#
# 8) **Export to CSV:** Save the DataFrame as a CSV file for further analysis.
# <br>
#
#
# By the end of this notebook you will have a clear understanding on how to extract and analyse football match data from UnderStat.

# %%
# Imports 

import requests 
from bs4 import BeautifulSoup
import json 
import pandas as pd

# %%
# Asking the user to input the desired match id and formatting the url 
# For our example, the match id for the Aston vs Arsenal game is = 26618
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id:'))
url = base_url+match


# Requests to get the webpage and beautiful soup to parse the page, lxml is a package used for processing XML in Python
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml' )

# Checking results 
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <base href="https://understat.com/"/>
# <title>Aston Villa 0 - 2 Arsenal (August 24 2024) | EPL | 2024/2025 | xG | Understat.com</title>
# <meta charset="utf-8"/>
# <meta content="Aston Villa 0 - 2 Arsenal. Check out detailed player statistic, goals, assists, key passes, xG, shot map, xGplot." name="description"/>
# <meta content="Aston Villa, Arsenal, EPL, 2024/2025, (August 24 2024), xG, expected goals, shot map" name="Keywords"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="understat" name="apple-mobile-web-app-title"/>
# <meta content="understat" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <link href="css/main.css?v=2.8" media="screen" rel="stylesheet"/>
# </head>
# <body class="theme-dark">
# <script>
# 			var THEME = localStorage.getItem("theme") || 'DARK';
# 			document.body.className = "theme-" + THEME.toLowerCase();
# 		</script>
# <div class="wrapper">
# <header class="clearfix" id="header">
# <div class="header-wrapper">
# <span class="block-match-result">
# <a href="https://understat.com/team/Aston_Villa/2024">Aston Villa</a> 0 - 2<a href="https://understat.com/team/Arsenal/2024">Arsenal</a>
# </span>
# <nav class="m-navigation-main">
# <ul class="h-inner">
# <li class="player-search">
# <input class="typeahead" placeholder="Find player by name" type="search"/>
# <span class="icon"><i class="fa fa-search"></i></span>
# </li>
# <li>
# <a class="link-icon" href="" title="Main page">
# <i aria-hidden="true" class="fas fa-home"></i>
# </a>
# </li>
# <li>
# <a class="link-icon" href="office" title="Personal cabinet">
# <i aria-hidden="true" class="fas fa-sign-in-alt"></i>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div class="preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <div class="preloader table-preloader is-hide" id="table-preloader">
# <div class="preloader-container">
# <div class="circ1"><div></div></div>
# <div class="circ2"><div></div></div>
# <div class="circ3"><div></div></div>
# <div class="circ4"><div></div></div>
# </div>
# </div>
# <input checked="" id="themes-switch" name="themes-switch" type="checkbox"/>
# <label for="themes-switch" title="Change theme"></label>
# <div class="page-wrapper">
# <div class="promotion">
# <ins class="adsbygoogle" data-ad-client="ca-pub-7470116180195095" data-ad-format="auto" data-ad-slot="2199699885" data-full-width-responsive="true" style="display:block"></ins>
# </div>
# <ul class="breadcrumb">
# <li><a href="https://understat.com/">Home</a></li>
# <li><a href="league/EPL/2024">EPL</a></li>
# <li>Aug 24 2024</li>
# </ul>
# <div class="block">
# <div class="block-content">
# <div class="block-match">
# <div class="filters">
# <div class="filter">
# <input checked="" id="scheme1" name="scheme" type="radio" value="field"/>
# <label for="scheme1">Field</label>
# <input id="scheme2" name="scheme" type="radio" value="chart"/>
# <label for="scheme2">Timing chart</label>
# <input id="scheme3" name="scheme" type="radio" value="stats"/>
# <label for="scheme3">Stats</label>
# </div>
# </div>
# <div class="scheme-block" data-scheme="field">
# <canvas id="field"></canvas>
# <div id="note" style="display:none;"></div>
# </div>
# <div class="scheme-block is-hide" data-scheme="chart">
# <div class="chart-container">
# <canvas id="chart"></canvas>
# </div>
# <div class="chartjs-tooltip is-hide team-home"></div>
# <div class="chartjs-tooltip is-hide team-away"></div>
# </div>
# <div class="scheme-block is-hide" data-scheme="stats">
# <div class="progress-bar teams-titles">
# <div class="progress-title">TEAMS</div>
# <div class="progress-home progress-over" style="width: 50%">
# <div class="progress-value">Aston Villa</div>
# </div>
# <div class="progress-away" style="width: 50%; left: 50%">
# <div class="progress-value">Arsenal</div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title">CHANCES</div>
# <div class="progress-home" style="width: 31%" title="31%">
# <div class="progress-value">31<small>%</small></div>
# </div>
# <div class="progress-draw" style="width: 30%; left: 31%" title="30%">
# <div class="progress-value">30<small>%</small></div>
# </div>
# <div class="progress-away" style="width: 39%" title="39%">
# <div class="progress-value">39<small>%</small></div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title">GOALS</div>
# <div class="progress-home" style="width: 0%" title="0%">
# <div class="progress-value">0</div>
# </div>
# <div class="progress-away progress-over" style="width: 100%; left: 0%" title="100%">
# <div class="progress-value">2</div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title">xG</div>
# <div class="progress-home" style="width: 48.217444326035%" title="48%">
# <div class="progress-value">1<span class="progress-value-decimal">.32</span></div>
# </div>
# <div class="progress-away progress-over" style="width: 51.782555673965%; left: 48.217444326035%" title="52%">
# <div class="progress-value">1<span class="progress-value-decimal">.41</span></div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title">SHOTS</div>
# <div class="progress-home progress-over" style="width: 55%" title="55%">
# <div class="progress-value">11</div>
# </div>
# <div class="progress-away" style="width: 45%; left: 55%" title="45%">
# <div class="progress-value">9</div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title">SHOTS ON TARGET</div>
# <div class="progress-home" style="width: 42.857142857143%" title="43%">
# <div class="progress-value">3</div>
# </div>
# <div class="progress-away progress-over" style="width: 57.142857142857%; left: 42.857142857143%" title="57%">
# <div class="progress-value">4</div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title" title="Passes completed within an estimated 20 yards of goal (crosses excluded)">DEEP</div>
# <div class="progress-home" style="width: 23.076923076923%" title="23%">
# <div class="progress-value">3</div>
# </div>
# <div class="progress-away progress-over" style="width: 76.923076923077%; left: 23.076923076923%" title="77%">
# <div class="progress-value">10</div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title" title="Passes allowed per defensive action in the opposition half">PPDA</div>
# <div class="progress-home" style="width: 25.240252519352%" title="25%">
# <div class="progress-value">17<span class="progress-value-decimal">.28</span></div>
# </div>
# <div class="progress-away progress-over" style="width: 74.759747480648%; left: 25.240252519352%" title="75%">
# <div class="progress-value">5<span class="progress-value-decimal">.83</span></div>
# </div>
# </div>
# <div class="progress-bar">
# <div class="progress-title" title="Expected points">xPTS</div>
# <div class="progress-home" style="width: 45.824220632391%" title="46%">
# <div class="progress-value">1<span class="progress-value-decimal">.24</span></div>
# </div>
# <div class="progress-away progress-over" style="width: 54.175779367609%; left: 45.824220632391%" title="54%">
# <div class="progress-value">1<span class="progress-value-decimal">.46</span></div>
# </div>
# </div>
# </div>
# <script>
# 	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22586301\x22,\x22minute\x22\x3A\x2224\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.8919999694824219\x22,\x22Y\x22\x3A\x220.56\x22,\x22xG\x22\x3A\x220.3767159879207611\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586304\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.779000015258789\x22,\x22Y\x22\x3A\x220.3920000076293945\x22,\x22xG\x22\x3A\x220.0289393812417984\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x2212412\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586305\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.3029999923706055\x22,\x22xG\x22\x3A\x220.05440268665552139\x22,\x22player\x22\x3A\x22Leon\x20Bailey\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225221\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22BallTouch\x22\x7D,\x7B\x22id\x22\x3A\x22586306\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8059999847412109\x22,\x22Y\x22\x3A\x220.5029999923706054\x22,\x22xG\x22\x3A\x220.05763914808630943\x22,\x22player\x22\x3A\x22Amadou\x20Onana\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x229667\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586307\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.94\x22,\x22Y\x22\x3A\x220.519000015258789\x22,\x22xG\x22\x3A\x220.4753965139389038\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22Head\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22Rebound\x22\x7D,\x7B\x22id\x22\x3A\x22586308\x22,\x22minute\x22\x3A\x2256\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.9009999847412109\x22,\x22Y\x22\x3A\x220.29700000762939455\x22,\x22xG\x22\x3A\x220.05026872456073761\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\ ...
# 		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2226618\x22,\x22fid\x22\x3A\x221821060\x22,\x22h\x22\x3A\x2271\x22,\x22a\x22\x3A\x2283\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222024\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Aston\x20Villa\x22,\x22team_a\x22\x3A\x22Arsenal\x22,\x22h_xg\x22\x3A\x221.31664\x22,\x22a_xg\x22\x3A\x221.41399\x22,\x22h_w\x22\x3A\x220.3113\x22,\x22h_d\x22\x3A\x220.3023\x22,\x22h_l\x22\x3A\x220.3864\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x2211\x22,\x22a_shot\x22\x3A\x229\x22,\x22h_shotOnTarget\x22\x3A\x223\x22,\x22a_shotOnTarget\x22\x3A\x224\x22,\x22h_deep\x22\x3A\x223\x22,\x22a_deep\x22\x3A\x2210\x22,\x22a_ppda\x22\x3A\x225.8333\x22,\x22h_ppda\x22\x3A\x2217.2778\x22\x7D');
# </script> </div>
# </div>
# <div class="roster roster-home">
# <h3><a href="https://understat.com/team/Aston_Villa/2024">Aston Villa</a></h3>
# <div class="players">
# <label class="player" data-id="4401" for="player_4401">
# <span class="player-check"></span>
# <span class="player-position">GK</span>
# <div class="player-name-container">
# <span class="player-name">Emiliano Martinez</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="8864" for="player_8864">
# <span class="player-check"></span>
# <span class="player-position">DR</span>
# <div class="player-name-container">
# <span class="player-name">Matthew Cash</span>
# </div>
# <span class="player-time">
# 	15'
# </span> </label>
# <label class="player" data-id="12775" for="player_12775">
# <span class="player-check"></span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Kosta Nedeljkovic</span>
# </div>
# <span class="player-time">
# 	75'
# </span> </label>
# <label class="player" data-id="7726" for="player_7726">
# <span class="player-check"></span>
# <span class="player-position">DC</span>
# <div class="player-name-container">
# <span class="player-name">Ezri Konsa Ngoyo</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="6221" for="player_6221">
# <span class="player-check"></span>
# <span class="player-position">DC</span>
# <div class="player-name-container">
# <span class="player-name">Pau Torres</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="1823" for="player_1823">
# <span class="player-check"></span>
# <span class="player-position">DL</span>
# <div class="player-name-container">
# <span class="player-name">Lucas Digne</span>
# </div>
# <span class="player-time">
# 	82'
# </span> </label>
# <label class="player" data-id="11807" for="player_11807">
# <span class="player-check"></span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Ian Maatsen</span>
# </div>
# <span class="player-time">
# 	8'
# </span> </label>
# <label class="player" data-id="5221" for="player_5221">
# <span class="player-check" title="1 Shot">
# <input id="player_5221" name="playersChecked[]" type="checkbox" value="5221"/>
# <label for="player_5221"></label>
# </span>
# <span class="player-position">MR</span>
# <div class="player-name-container">
# <span class="player-name">Leon Bailey</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="5956" for="player_5956">
# <span class="player-check"></span>
# <span class="player-position">MC</span>
# <div class="player-name-container">
# <span class="player-name">Youri Tielemans</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="9667" for="player_9667">
# <span class="player-check" title="2 Shots">
# <input id="player_9667" name="playersChecked[]" type="checkbox" value="9667"/>
# <label for="player_9667"></label>
# </span>
# <span class="player-position">MC</span>
# <div class="player-name-container">
# <span class="player-name">Amadou Onana</span>
# </div>
# <span class="player-cards">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i>
# </span>
# <span class="player-time">
# 	82'
# </span> </label>
# <label class="player" data-id="592" for="player_592">
# <span class="player-check" title="1 Shot">
# <input id="player_592" name="playersChecked[]" type="checkbox" value="592"/>
# <label for="player_592"></label>
# </span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Ross Barkley</span>
# </div>
# <span class="player-time">
# 	8'
# </span> </label>
# <label class="player" data-id="7723" for="player_7723">
# <span class="player-check"></span>
# <span class="player-position">ML</span>
# <div class="player-name-container">
# <span class="player-name">John McGinn</span>
# </div>
# <span class="player-time">
# 	71'
# </span> </label>
# <label class="player" data-id="8941" for="player_8941">
# <span class="player-check" title="1 Shot">
# <input id="player_8941" name="playersChecked[]" type="checkbox" value="8941"/>
# <label for="player_8941"></label>
# </span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Jacob Ramsey</span>
# </div>
# <span class="player-time">
# 	19'
# </span> </label>
# <label class="player" data-id="12412" for="player_12412">
# <span class="player-check" title="3 Shots">
# <input id="player_12412" name="playersChecked[]" type="checkbox" value="12412"/>
# <label for="player_12412"></label>
# </span>
# <span class="player-position">FW</span>
# <div class="player-name-container">
# <span class="player-name">Morgan Rogers</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="8865" for="player_8865">
# <span class="player-check" title="2 Shots">
# <input id="player_8865" name="playersChecked[]" type="checkbox" value="8865"/>
# <label for="player_8865"></label>
# </span>
# <span class="player-position">FW</span>
# <div class="player-name-container">
# <span class="player-name">Ollie Watkins</span>
# </div>
# <span class="player-time">
# 	71'
# </span> </label>
# <label class="player" data-id="11366" for="player_11366">
# <span class="player-check" title="1 Shot">
# <input id="player_11366" name="playersChecked[]" type="checkbox" value="11366"/>
# <label for="player_11366"></label>
# </span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Jhon Durán</span>
# </div>
# <span class="player-time">
# 	19'
# </span> </label>
# </div>
# </div> <div class="roster roster-away">
# <h3><a href="https://understat.com/team/Arsenal/2024">Arsenal</a></h3>
# <div class="players">
# <label class="player" data-id="9676" for="player_9676">
# <span class="player-check"></span>
# <span class="player-position">GK</span>
# <div class="player-name-container">
# <span class="player-name">David Raya</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="7298" for="player_7298">
# <span class="player-check"></span>
# <span class="player-position">DR</span>
# <div class="player-name-container">
# <span class="player-name">Ben White</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="5613" for="player_5613">
# <span class="player-check"></span>
# <span class="player-position">DC</span>
# <div class="player-name-container">
# <span class="player-name">Gabriel</span>
# </div>
# <span class="player-cards">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i>
# </span>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="6888" for="player_6888">
# <span class="player-check"></span>
# <span class="player-position">DC</span>
# <div class="player-name-container">
# <span class="player-name">William Saliba</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="11707" for="player_11707">
# <span class="player-check"></span>
# <span class="player-position">DL</span>
# <div class="player-name-container">
# <span class="player-name">Jurriën Timber</span>
# </div>
# <span class="player-time">
# 	86'
# </span> </label>
# <label class="player" data-id="8129" for="player_8129">
# <span class="player-check"></span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Riccardo Calafiori</span>
# </div>
# <span class="player-time">
# 	4'
# </span> </label>
# <label class="player" data-id="5553" for="player_5553">
# <span class="player-check" title="1 Shot">
# <input id="player_5553" name="playersChecked[]" type="checkbox" value="5553"/>
# <label for="player_5553"></label>
# </span>
# <span class="player-position">MC</span>
# <div class="player-name-container">
# <span class="player-name">Declan Rice</span>
# </div>
# <span class="player-cards">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i>
# </span>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="2328" for="player_2328">
# <span class="player-check" title="2 Shots">
# <input id="player_2328" name="playersChecked[]" type="checkbox" value="2328"/>
# <label for="player_2328"></label>
# </span>
# <span class="player-position">MC</span>
# <div class="player-name-container">
# <span class="player-name">Thomas Partey</span>
# </div>
# <span class="player-goals">
# <span class="goal" title="Goal"></span>
# </span>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="2517" for="player_2517">
# <span class="player-check" title="1 Shot">
# <input id="player_2517" name="playersChecked[]" type="checkbox" value="2517"/>
# <label for="player_2517"></label>
# </span>
# <span class="player-position">MC</span>
# <div class="player-name-container">
# <span class="player-name">Martin Odegaard</span>
# </div>
# <span class="player-cards">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i>
# </span>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="7322" for="player_7322">
# <span class="player-check" title="1 Shot">
# <input id="player_7322" name="playersChecked[]" type="checkbox" value="7322"/>
# <label for="player_7322"></label>
# </span>
# <span class="player-position">FWR</span>
# <div class="player-name-container">
# <span class="player-name">Bukayo Saka</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="6492" for="player_6492">
# <span class="player-check"></span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Reiss Nelson</span>
# </div>
# <span class="player-time">
# 	1'
# </span> </label>
# <label class="player" data-id="5220" for="player_5220">
# <span class="player-check" title="1 Shot">
# <input id="player_5220" name="playersChecked[]" type="checkbox" value="5220"/>
# <label for="player_5220"></label>
# </span>
# <span class="player-position">FW</span>
# <div class="player-name-container">
# <span class="player-name">Kai Havertz</span>
# </div>
# <span class="player-time">
# 	90'
# </span> </label>
# <label class="player" data-id="7752" for="player_7752">
# <span class="player-check"></span>
# <span class="player-position">FWL</span>
# <div class="player-name-container">
# <span class="player-name">Gabriel Martinelli</span>
# </div>
# <span class="player-time">
# 	71'
# </span> </label>
# <label class="player" data-id="7698" for="player_7698">
# <span class="player-check" title="3 Shots">
# <input id="player_7698" name="playersChecked[]" type="checkbox" value="7698"/>
# <label for="player_7698"></label>
# </span>
# <span class="player-position">Sub</span>
# <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="substitution"></i>
# <div class="player-name-container">
# <span class="player-name">Leandro Trossard</span>
# </div>
# <span class="player-goals">
# <span class="goal" title="Goal"></span>
# </span>
# <span class="player-time">
# 	19'
# </span> </label>
# </div>
# </div></div>
# <div class="block">
# <div class="timiline-block">
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/8864">Matthew Cash</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/12775">Kosta Nedeljkovic</a>
# </div>
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">15'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">48'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i> <a class="player-name" href="https://understat.com/player/5553">Declan Rice</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">56'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i> <a class="player-name" href="https://understat.com/player/5613">Gabriel</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">66'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <i aria-hidden="true" class="fas fa-futbol" title="Goal"></i> <span class="match-score">0 - 1</span> <a class="player-name" href="https://understat.com/player/7698">Leandro Trossard</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/9667">Amadou Onana</a> <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i>
# </div>
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/8865">Ollie Watkins</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/11366">Jhon Durán</a>
# </div>
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/7723">John McGinn</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/8941">Jacob Ramsey</a>
# </div>
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">71'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/7752">Gabriel Martinelli</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/7698">Leandro Trossard</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">76'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <i aria-hidden="true" class="fas fa-futbol" title="Goal"></i> <span class="match-score">0 - 2</span> <a class="player-name" href="https://understat.com/player/2328">Thomas Partey</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/1823">Lucas Digne</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/11807">Ian Maatsen</a>
# </div>
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/9667">Amadou Onana</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/592">Ross Barkley</a>
# </div>
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">82'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">86'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/11707">Jurriën Timber</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/8129">Riccardo Calafiori</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">88'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <i aria-hidden="true" class="fas fa-square yellow-card" title="Yellow card"></i> <a class="player-name" href="https://understat.com/player/2517">Martin Odegaard</a>
# </div>
# </div>
# </div>
# </div>
# <div class="timiline-container">
# <div class="timeline-left">
# <div class="timeline-block block-home">
# </div>
# </div>
# <div class="timeline-minute">
# <span class="minute-value">94'</span>
# </div>
# <div class="timeline-right">
# <div class="timeline-block block-away">
# <div class="timeline-row">
# <a class="player-name" href="https://understat.com/player/7322">Bukayo Saka</a> <i aria-hidden="true" class="fas fa-exchange-alt player-substitution" title="Substitution"></i> <a class="player-name" href="https://understat.com/player/6492">Reiss Nelson</a>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# <div class="block">
# <div class="block-content">
# <div class="filters">
# <div class="filter">
# <input checked="" id="team-home" name="team" type="radio" value="h"/>
# <label for="team-home">Aston Villa</label>
# <input id="team-away" name="team" type="radio" value="a"/>
# <label for="team-away">Arsenal</label>
# </div>
# </div>
# <div class="rosters margin-top" id="match-rosters"></div>
# <script>
# 	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22668259\x22\x3A\x7B\x22id\x22\x3A\x22668259\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x224401\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22Emiliano\x20Martinez\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.10713031142950058\x22,\x22xGBuildup\x22\x3A\x220.10713031142950058\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22668260\x22\x3A\x7B\x22id\x22\x3A\x22668260\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2215\x22,\x22player_id\x22\x3A\x228864\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Matthew\x20Cash\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22668274\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22668262\x22\x3A\x7B\x22id\x22\x3A\x22668262\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227726\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Ezri\x20Konsa\x20Ngoyo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.0289393812417984\x22,\x22xGBuildup\x22\x3A\x220.0289393812417984\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22668261\x22\x3A\x7B\x22id\x22\x3A\x22668261\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x226221\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Pau\x20Torres\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.13606970012187958\x22,\x22xGBuildup\x22\x3A\x220.13606970012187958\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22668263\x22\x3A\x7B\x22id\x22\x3A\x22668263\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2282\x22,\x22player_id\x22\x3A\x221823\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Lucas\x20Digne\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22668271\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.0289393812417984\x22,\x22xGBuildup\x22\x3A\x220.0289393812417984\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22668264\x22\x3A\x7B\x22id\x22\x3A\x22668264\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.05440268665552139\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x225221\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22MR\x22,\x22player\x22\x3A\x22Leon\x20Bailey\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x ...
# </script> </div>
# </div>
# </div>
# <div class="overlay is-hide"></div>
# <div class="modal is-hide">
# <div class="modal-header">
# <div class="modal-title"></div>
# <span class="modal-close"></span>
# </div>
# <div class="modal-body"></div>
# </div>
# <div class="grass-container">
# <div class="grass"></div>
# <div class="grass"></div>
# </div>
# <footer id="footer">
# <div class="footer-wrapper">
# <ul>
# <li><a href="league/EPL">EPL</a></li>
# <li><a href="league/La_liga">La liga</a></li>
# <li><a href="league/Bundesliga">Bundesliga</a></li>
# <li><a href="league/Serie_A">Serie A</a></li>
# <li><a href="league/Ligue_1">Ligue 1</a></li>
# <li><a href="league/RFPL">RFPL</a></li>
# </ul>
# <div><a href="mailto:support@understat.com">support@understat.com</a></div>
# <div>© understat 2017</div>
# </div>
# </footer>
# </div>
# <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>
# <script>
# 		WebFont.load({
# 			google: {
# 				families: ['Barlow:500', 'Anton']
# 			},
# 			active: function(){
# 				flagFontsLoading = true;
# 			}
# 		});
# 		var BASE_URL = 'https://understat.com/',
# 			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224330\x22\x7D') ;
# 	</script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>
# <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>
# <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>
# <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>
# <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>
# <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>
# <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>
# <script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		ga('create', 'UA-101482034-1', 'auto');
# 		ga('send', 'pageview');
#
# 					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
# 			</script>
# <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>
# </body>
# </html>

# %%
# Parsing through for script tags 
scripts = soup.find_all('script')
print(scripts)
# Out:
# [<script>
# 			var THEME = localStorage.getItem("theme") || 'DARK';
# 			document.body.className = "theme-" + THEME.toLowerCase();
# 		</script>, <script>
# 	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22586301\x22,\x22minute\x22\x3A\x2224\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.8919999694824219\x22,\x22Y\x22\x3A\x220.56\x22,\x22xG\x22\x3A\x220.3767159879207611\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586304\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.779000015258789\x22,\x22Y\x22\x3A\x220.3920000076293945\x22,\x22xG\x22\x3A\x220.0289393812417984\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x2212412\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586305\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.3029999923706055\x22,\x22xG\x22\x3A\x220.05440268665552139\x22,\x22player\x22\x3A\x22Leon\x20Bailey\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225221\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22BallTouch\x22\x7D,\x7B\x22id\x22\x3A\x22586306\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8059999847412109\x22,\x22Y\x22\x3A\x220.5029999923706054\x22,\x22xG\x22\x3A\x220.05763914808630943\x22,\x22player\x22\x3A\x22Amadou\x20Onana\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x229667\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586307\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.94\x22,\x22Y\x22\x3A\x220.519000015258789\x22,\x22xG\x22\x3A\x220.4753965139389038\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22Head\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22Rebound\x22\x7D,\x7B\x22id\x22\x3A\x22586308\x22,\x22minute\x22\x3A\x2256\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.9009999847412109\x22,\x22Y\x22\x3A\x220.29700000762939455\x22,\x22xG\x22\x3A\x220.05026872456073761\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\ ...
# 		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2226618\x22,\x22fid\x22\x3A\x221821060\x22,\x22h\x22\x3A\x2271\x22,\x22a\x22\x3A\x2283\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222024\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Aston\x20Villa\x22,\x22team_a\x22\x3A\x22Arsenal\x22,\x22h_xg\x22\x3A\x221.31664\x22,\x22a_xg\x22\x3A\x221.41399\x22,\x22h_w\x22\x3A\x220.3113\x22,\x22h_d\x22\x3A\x220.3023\x22,\x22h_l\x22\x3A\x220.3864\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x2211\x22,\x22a_shot\x22\x3A\x229\x22,\x22h_shotOnTarget\x22\x3A\x223\x22,\x22a_shotOnTarget\x22\x3A\x224\x22,\x22h_deep\x22\x3A\x223\x22,\x22a_deep\x22\x3A\x2210\x22,\x22a_ppda\x22\x3A\x225.8333\x22,\x22h_ppda\x22\x3A\x2217.2778\x22\x7D');
# </script>, <script>
# 	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22668259\x22\x3A\x7B\x22id\x22\x3A\x22668259\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x224401\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22Emiliano\x20Martinez\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.10713031142950058\x22,\x22xGBuildup\x22\x3A\x220.10713031142950058\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22668260\x22\x3A\x7B\x22id\x22\x3A\x22668260\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2215\x22,\x22player_id\x22\x3A\x228864\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Matthew\x20Cash\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22668274\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22668262\x22\x3A\x7B\x22id\x22\x3A\x22668262\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227726\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Ezri\x20Konsa\x20Ngoyo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.0289393812417984\x22,\x22xGBuildup\x22\x3A\x220.0289393812417984\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22668261\x22\x3A\x7B\x22id\x22\x3A\x22668261\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x226221\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Pau\x20Torres\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.13606970012187958\x22,\x22xGBuildup\x22\x3A\x220.13606970012187958\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22668263\x22\x3A\x7B\x22id\x22\x3A\x22668263\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2282\x22,\x22player_id\x22\x3A\x221823\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Lucas\x20Digne\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22668271\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.0289393812417984\x22,\x22xGBuildup\x22\x3A\x220.0289393812417984\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22668264\x22\x3A\x7B\x22id\x22\x3A\x22668264\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.05440268665552139\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x225221\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22MR\x22,\x22player\x22\x3A\x22Leon\x20Bailey\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x ...
# </script>, <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>, <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>, <script>
# 		WebFont.load({
# 			google: {
# 				families: ['Barlow:500', 'Anton']
# 			},
# 			active: function(){
# 				flagFontsLoading = true;
# 			}
# 		});
# 		var BASE_URL = 'https://understat.com/',
# 			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224330\x22\x7D') ;
# 	</script>, <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>, <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>, <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>, <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>, <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>, <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>, <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>, <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>, <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>, <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>, <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>, <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>, <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>, <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>, <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>, <script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		ga('create', 'UA-101482034-1', 'auto');
# 		ga('send', 'pageview');
#
# 					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
# 			</script>, <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
# Getting the shots data only 
strings = scripts[1].string
print(strings)
# Out:
# 	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22586301\x22,\x22minute\x22\x3A\x2224\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.8919999694824219\x22,\x22Y\x22\x3A\x220.56\x22,\x22xG\x22\x3A\x220.3767159879207611\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586304\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.779000015258789\x22,\x22Y\x22\x3A\x220.3920000076293945\x22,\x22xG\x22\x3A\x220.0289393812417984\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x2212412\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586305\x22,\x22minute\x22\x3A\x2243\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.3029999923706055\x22,\x22xG\x22\x3A\x220.05440268665552139\x22,\x22player\x22\x3A\x22Leon\x20Bailey\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225221\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Ollie\x20Watkins\x22,\x22lastAction\x22\x3A\x22BallTouch\x22\x7D,\x7B\x22id\x22\x3A\x22586306\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8059999847412109\x22,\x22Y\x22\x3A\x220.5029999923706054\x22,\x22xG\x22\x3A\x220.05763914808630943\x22,\x22player\x22\x3A\x22Amadou\x20Onana\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x229667\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Rogers\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22586307\x22,\x22minute\x22\x3A\x2253\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.94\x22,\x22Y\x22\x3A\x220.519000015258789\x22,\x22xG\x22\x3A\x220.4753965139389038\x22,\x22player\x22\x3A\x22Ollie\x20Watkins\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x228865\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22Head\x22,\x22match_id\x22\x3A\x2226618\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Arsenal\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22Rebound\x22\x7D,\x7B\x22id\x22\x3A\x22586308\x22,\x22minute\x22\x3A\x2256\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.9009999847412109\x22,\x22Y\x22\x3A\x220.29700000762939455\x22,\x22xG\x22\x3A\x220.05026872456073761\x22,\x22player\x22\x3A\x22Morgan\x20Rogers\x22,\ ...
# 		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2226618\x22,\x22fid\x22\x3A\x221821060\x22,\x22h\x22\x3A\x2271\x22,\x22a\x22\x3A\x2283\x22,\x22date\x22\x3A\x222024\x2D08\x2D24\x2016\x3A30\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222024\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Aston\x20Villa\x22,\x22team_a\x22\x3A\x22Arsenal\x22,\x22h_xg\x22\x3A\x221.31664\x22,\x22a_xg\x22\x3A\x221.41399\x22,\x22h_w\x22\x3A\x220.3113\x22,\x22h_d\x22\x3A\x220.3023\x22,\x22h_l\x22\x3A\x220.3864\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x2211\x22,\x22a_shot\x22\x3A\x229\x22,\x22h_shotOnTarget\x22\x3A\x223\x22,\x22a_shotOnTarget\x22\x3A\x224\x22,\x22h_deep\x22\x3A\x223\x22,\x22a_deep\x22\x3A\x2210\x22,\x22a_ppda\x22\x3A\x225.8333\x22,\x22h_ppda\x22\x3A\x2217.2778\x22\x7D');

# %%
# Locate the start and end indices of the JSON data within the string
ind_start = strings.index("('")+2
ind_end = strings.index("')")

# Extract and clean the JSON data
json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape') #this is often done to interpret an escape seqeunces (like /n and /t) present in the string 

# Convert the cleaned JSON string to a Python dictionary
data = json.loads(json_data)
data
# Out:
# {'h': [{'id': '586301',
#    'minute': '24',
#    'result': 'MissedShots',
#    'X': '0.8919999694824219',
#    'Y': '0.56',
#    'xG': '0.3767159879207611',
#    'player': 'Ollie Watkins',
#    'h_a': 'h',
#    'player_id': '8865',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Morgan Rogers',
#    'lastAction': 'Pass'},
#   {'id': '586304',
#    'minute': '43',
#    'result': 'BlockedShot',
#    'X': '0.779000015258789',
#    'Y': '0.3920000076293945',
#    'xG': '0.0289393812417984',
#    'player': 'Morgan Rogers',
#    'h_a': 'h',
#    'player_id': '12412',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'Pass'},
#   {'id': '586305',
#    'minute': '43',
#    'result': 'SavedShot',
#    'X': '0.899000015258789',
#    'Y': '0.3029999923706055',
#    'xG': '0.05440268665552139',
#    'player': 'Leon Bailey',
#    'h_a': 'h',
#    'player_id': '5221',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'BallTouch'},
#   {'id': '586306',
#    'minute': '53',
#    'result': 'BlockedShot',
#    'X': '0.8059999847412109',
#    'Y': '0.5029999923706054',
#    'xG': '0.05763914808630943',
#    'player': 'Amadou Onana',
#    'h_a': 'h',
#    'player_id': '9667',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Morgan Rogers',
#    'lastAction': 'Pass'},
#   {'id': '586307',
#    'minute': '53',
#    'result': 'SavedShot',
#    'X': '0.94',
#    'Y': '0.519000015258789',
#    'xG': '0.4753965139389038',
#    'player': 'Ollie Watkins',
#    'h_a': 'h',
#    'player_id': '8865',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '586308',
#    'minute': '56',
#    'result': 'BlockedShot',
#    'X': '0.9009999847412109',
#    'Y': '0.29700000762939455',
#    'xG': '0.05026872456073761',
#    'player': 'Morgan Rogers',
#    'h_a': 'h',
#    'player_id': '12412',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Leon Bailey',
#    'lastAction': 'Pass'},
#   {'id': '586309',
#    'minute': '57',
#    'result': 'MissedShots',
#    'X': '0.894000015258789',
#    'Y': '0.500999984741211',
#    'xG': '0.054350513964891434',
#    'player': 'Amadou Onana',
#    'h_a': 'h',
#    'player_id': '9667',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Youri Tielemans',
#    'lastAction': 'Cross'},
#   {'id': '586310',
#    'minute': '60',
#    'result': 'BlockedShot',
#    'X': '0.8190000152587891',
#    'Y': '0.34799999237060547',
#    'xG': '0.12375395745038986',
#    'player': 'Morgan Rogers',
#    'h_a': 'h',
#    'player_id': '12412',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Youri Tielemans',
#    'lastAction': 'TakeOn'},
#   {'id': '586315',
#    'minute': '83',
#    'result': 'SavedShot',
#    'X': '0.8730000305175781',
#    'Y': '0.6469999694824219',
#    'xG': '0.042012423276901245',
#    'player': 'Jacob Ramsey',
#    'h_a': 'h',
#    'player_id': '8941',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '586316',
#    'minute': '86',
#    'result': 'BlockedShot',
#    'X': '0.924000015258789',
#    'Y': '0.5940000152587891',
#    'xG': '0.06511788815259933',
#    'player': 'Jhon Durán',
#    'h_a': 'h',
#    'player_id': '11366',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Ian Maatsen',
#    'lastAction': 'Cross'},
#   {'id': '586317',
#    'minute': '90',
#    'result': 'MissedShots',
#    'X': '0.7759999847412109',
#    'Y': '0.644000015258789',
#    'xG': '0.015442472882568836',
#    'player': 'Ross Barkley',
#    'h_a': 'h',
#    'player_id': '592',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Jacob Ramsey',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '586299',
#    'minute': '6',
#    'result': 'SavedShot',
#    'X': '0.8719999694824219',
#    'Y': '0.7090000152587891',
#    'xG': '0.0387347973883152',
#    'player': 'Declan Rice',
#    'h_a': 'a',
#    'player_id': '5553',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '586300',
#    'minute': '15',
#    'result': 'SavedShot',
#    'X': '0.8669999694824219',
#    'Y': '0.34400001525878904',
#    'xG': '0.06579126417636871',
#    'player': 'Bukayo Saka',
#    'h_a': 'a',
#    'player_id': '7322',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Martin Odegaard',
#    'lastAction': 'Pass'},
#   {'id': '586302',
#    'minute': '31',
#    'result': 'MissedShots',
#    'X': '0.745999984741211',
#    'Y': '0.625999984741211',
#    'xG': '0.01506333239376545',
#    'player': 'Thomas Partey',
#    'h_a': 'a',
#    'player_id': '2328',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Gabriel Martinelli',
#    'lastAction': 'Pass'},
#   {'id': '586303',
#    'minute': '38',
#    'result': 'MissedShots',
#    'X': '0.955',
#    'Y': '0.5479999923706055',
#    'xG': '0.614169716835022',
#    'player': 'Kai Havertz',
#    'h_a': 'a',
#    'player_id': '5220',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Gabriel Martinelli',
#    'lastAction': 'Pass'},
#   {'id': '586311',
#    'minute': '66',
#    'result': 'Goal',
#    'X': '0.8690000152587891',
#    'Y': '0.565',
#    'xG': '0.07451161742210388',
#    'player': 'Leandro Trossard',
#    'h_a': 'a',
#    'player_id': '7698',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '586312',
#    'minute': '76',
#    'result': 'Goal',
#    'X': '0.8119999694824219',
#    'Y': '0.4129999923706055',
#    'xG': '0.051377709954977036',
#    'player': 'Thomas Partey',
#    'h_a': 'a',
#    'player_id': '2328',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Bukayo Saka',
#    'lastAction': 'Pass'},
#   {'id': '586313',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.8930000305175781',
#    'Y': '0.47099998474121096',
#    'xG': '0.483364999294281',
#    'player': 'Martin Odegaard',
#    'h_a': 'a',
#    'player_id': '2517',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Declan Rice',
#    'lastAction': 'Pass'},
#   {'id': '586314',
#    'minute': '82',
#    'result': 'MissedShots',
#    'X': '0.779000015258789',
#    'Y': '0.6630000305175782',
#    'xG': '0.027705498039722443',
#    'player': 'Leandro Trossard',
#    'h_a': 'a',
#    'player_id': '7698',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Bukayo Saka',
#    'lastAction': 'Pass'},
#   {'id': '586318',
#    'minute': '93',
#    'result': 'BlockedShot',
#    'X': '0.7380000305175781',
#    'Y': '0.5420000076293945',
#    'xG': '0.043267685920000076',
#    'player': 'Leandro Trossard',
#    'h_a': 'a',
#    'player_id': '7698',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26618',
#    'h_team': 'Aston Villa',
#    'a_team': 'Arsenal',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-08-24 16:30:00',
#    'player_assisted': 'Martin Odegaard',
#    'lastAction': 'Pass'}]}

# %%
# Initialising a series of lists which will compose our pandas dataframe 
# Seperating the data for the home and away teams
x = [] # x pitch coordinates of the shot position
y = [] # y pitch coordinates of the shot position
xG = [] # xG from the shot  
result = [] # outcome of the shot
last_action = [] # action taken before the shot 
situation = [] # pitch situation before the shot was taken
team = [] # team name of the shot maker 
player = [] # player name of the shot maker
data_away = data['a'] # all away teams shot information
data_home = data['h'] # all home teams shot information

# %%
# Obtaining the home teams shot data from the results to append into the relevant lists 
for index in range(len(data_home)): 
    for key in data_home[index] : 
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y' : 
            y.append(data_home[index][key])
        if key == 'h_team' : 
            team.append(data_home[index][key])
        if key == 'xG' : 
            xG.append(data_home[index][key]) 
        if key == 'player' :
            player.append(data_home[index][key])
        if key == 'lastAction' : 
            last_action.append(data_home[index][key])
        if key == 'result' : 
            result.append(data_home[index][key])
        if key == 'situation' : 
            situation.append(data_home[index][key])

# %%
# Obtaining the away teams data from the results to append into the relevant lists 
for index in range(len(data_away)): 
    for key in data_away[index] : 
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y' : 
            y.append(data_away[index][key])
        if key == 'a_team' : 
            team.append(data_away[index][key])
        if key == 'xG' : 
            xG.append(data_away[index][key]) 
        if key == 'player' :
            player.append(data_away[index][key])
        if key == 'lastAction' : 
            last_action.append(data_away[index][key])
        if key == 'result' : 
            result.append(data_away[index][key])
        if key == 'situation' : 
            situation.append(data_away[index][key])

# %%
# Checking that all lists are the same length, in order to form the pandas dataframe
list_length = len(situation)

if all(len(lst) == list_length for lst in [team, player, x, y, xG, result, last_action, situation]) : 
    print('All of the lists have the same length')
else : 
    print('The lists do not all have the same length')
# Out:
# All of the lists have the same length

# %%
# Making the pandas dataframe
col_names = ['team_name', 'player_name', 'X', 'Y', 'xG', 'result','last_action', 'situation']
df = pd.DataFrame([team, player, x, y, xG, result, last_action, situation], index = col_names)

# Transposing the dataframe 
df.T
# Out:
#       team_name       player_name                   X                    Y  \
# 0   Aston Villa     Ollie Watkins  0.8919999694824219                 0.56
# 1   Aston Villa     Morgan Rogers   0.779000015258789   0.3920000076293945
# 2   Aston Villa       Leon Bailey   0.899000015258789   0.3029999923706055
# 3   Aston Villa      Amadou Onana  0.8059999847412109   0.5029999923706054
# 4   Aston Villa     Ollie Watkins                0.94    0.519000015258789
# 5   Aston Villa     Morgan Rogers  0.9009999847412109  0.29700000762939455
# 6   Aston Villa      Amadou Onana   0.894000015258789    0.500999984741211
# 7   Aston Villa     Morgan Rogers  0.8190000152587891  0.34799999237060547
# 8   Aston Villa      Jacob Ramsey  0.8730000305175781   0.6469999694824219
# 9   Aston Villa        Jhon Durán   0.924000015258789   0.5940000152587891
# 10  Aston Villa      Ross Barkley  0.7759999847412109    0.644000015258789
# 11      Arsenal       Declan Rice  0.8719999694824219   0.7090000152587891
# 12      Arsenal       Bukayo Saka  0.8669999694824219  0.34400001525878904
# 13      Arsenal     Thomas Partey   0.745999984741211    0.625999984741211
# 14      Arsenal       Kai Havertz               0.955   0.5479999923706055
# 15      Arsenal  Leandro Trossard  0.8690000152587891                0.565
# 16      Arsenal     Thomas Partey  0.8119999694824219   0.4129999923706055
# 17      Arsenal   Martin Odegaard  0.8930000305175781  0.47099998474121096
# 18      Arsenal  Leandro Trossard   0.779000015258789   0.6630000305175782
# 19      Arsenal  Leandro Trossard  0.7380000305175781   0.5420000076293945
#
#                       xG       result last_action   situation
# 0     0.3767159879207611  MissedShots        Pass    OpenPlay
# 1     0.0289393812417984  BlockedShot        Pass    OpenPlay
# 2    0.05440268665552139    SavedShot   BallTouch    OpenPlay
# 3    0.05763914808630943  BlockedShot        Pass    OpenPlay
# 4     0.4753965139389038    SavedShot     Rebound    OpenPlay
# 5    0.05026872456073761  BlockedShot        Pass    OpenPlay
# 6   0.054350513964891434  MissedShots       Cross  FromCorner
# 7    0.12375395745038986  BlockedShot      TakeOn    OpenPlay
# 8   0.042012423276901245    SavedShot        None    OpenPlay
# 9    0.06511788815259933  BlockedShot       Cross    OpenPlay
# 10  0.015442472882568836  MissedShots        Pass    OpenPlay
# 11    0.0387347973883152    SavedShot        None    OpenPlay
# 12   0.06579126417636871    SavedShot        Pass    OpenPlay
# 13   0.01506333239376545  MissedShots        Pass    OpenPlay
# 14     0.614169716835022  MissedShots        Pass    OpenPlay
# 15   0.07451161742210388         Goal        None    OpenPlay
# 16  0.051377709954977036         Goal        Pass    OpenPlay
# 17     0.483364999294281  MissedShots        Pass    OpenPlay
# 18  0.027705498039722443  MissedShots        Pass    OpenPlay
# 19  0.043267685920000076  BlockedShot        Pass    OpenPlay

# %%
# Exporting the dataframe to a .csv file 
df.to_csv('avfc_afc_2425.csv', index = False )
